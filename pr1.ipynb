# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1
# 2                               Heikkinen, Miss. Laina    1   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1
# 4                             Allen, Mr. William Henry    0   35      0
# ..                                                 ...  ...  ...    ...
# 886                              Montvila, Rev. Juozas    0   27      0
# 887                       Graham, Miss. Margaret Edith    1   19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    1   29      1
# 889                              Behr, Mr. Karl Howell    0   26      0
# 890                                Dooley, Mr. Patrick    0   32      0
#
#      Parch            Ticket     Fare Cabin  Fare_normalized  Embarked_C  \
# 0        0         A/5 21171   7.2500   NaN         0.014151       False
# 1        0          PC 17599  71.2833   C85         0.139136        True
# 2        0  STON/O2. 3101282   7.9250   NaN         0.015469       False
# 3        0            113803  53.1000  C123         0.103644       False
# 4        0            373450   8.0500   NaN         0.015713       False
# ..     ...               ...      ...   ...              ...         ...
# 886      0            211536  13.0000   NaN         0.025374       False
# 887      0            112053  30.0000   B42         0.058556       False
# 888      2        W./C. 6607  23.4500   NaN         0.045771       False
# 889      0            111369  30.0000  C148         0.058556        True
# 890      0            370376   7.7500   NaN         0.015127       False
#
#      Embarked_Q  Embarked_S
# 0         False        True
# 1         False       False
# 2         False        True
# 3         False        True
# 4         False        True
# ..          ...         ...
# 886       False        True
# 887       False        True
# 888       False        True
# 889       False       False
# 890        True       False
#
# [891 rows x 15 columns]

# %%
df['Age'] = df['Age'].astype(int)
df['Fare'] = df['Fare'].astype(float)

# %%
df['Fare_normalized'] = (df['Fare'] - df['Fare'].min()) / (df['Fare'].max() - df['Fare'].min())

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# %%
df = pd.get_dummies(df, columns=['Embarked'])

# %%
df_filtered = df[df['Age'] > 30]
df_filtered.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 11           12         1       1
#
#                                                  Name  Sex  Age  SibSp  Parch  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                            Allen, Mr. William Henry    0   35      0      0
# 6                             McCarthy, Mr. Timothy J    0   54      0      0
# 11                           Bonnell, Miss. Elizabeth    1   58      0      0
#
#       Ticket     Fare Cabin  Fare_normalized  Embarked_C  Embarked_Q  \
# 1   PC 17599  71.2833   C85         0.139136        True       False
# 3     113803  53.1000  C123         0.103644       False       False
# 4     373450   8.0500   NaN         0.015713       False       False
# 6      17463  51.8625   E46         0.101229       False       False
# 11    113783  26.5500  C103         0.051822       False       False
#
#     Embarked_S
# 1        False
# 3         True
# 4         True
# 6         True
# 11        True

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df.drop_duplicates(inplace=True)

# %%
df1 = df[['PassengerId', 'Age']]
df2 = df[['PassengerId', 'Fare']]

merged_df = pd.merge(df1, df2, on='PassengerId')
merged_df.head()
# Out:
#    PassengerId  Age     Fare
# 0            1   22   7.2500
# 1            2   38  71.2833
# 2            3   26   7.9250
# 3            4   35  53.1000
# 4            5   35   8.0500

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
#
#              Ticket     Fare Cabin  Fare_normalized  Embarked_C  Embarked_Q  \
# 0         A/5 21171   7.2500   NaN         0.014151       False       False
# 1          PC 17599  71.2833   C85         0.139136        True       False
# 2  STON/O2. 3101282   7.9250   NaN         0.015469       False       False
# 3            113803  53.1000  C123         0.103644       False       False
# 4            373450   8.0500   NaN         0.015713       False       False
#
#    Embarked_S
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True

# %%
print(df['Name'])
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %%
df['Age'] = df['Age'].ffill()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1
# 2                               Heikkinen, Miss. Laina    1   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1
# 4                             Allen, Mr. William Henry    0   35      0
# ..                                                 ...  ...  ...    ...
# 886                              Montvila, Rev. Juozas    0   27      0
# 887                       Graham, Miss. Margaret Edith    1   19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    1   29      1
# 889                              Behr, Mr. Karl Howell    0   26      0
# 890                                Dooley, Mr. Patrick    0   32      0
#
#      Parch            Ticket     Fare Cabin  Fare_normalized  Embarked_C  \
# 0        0         A/5 21171   7.2500   NaN         0.014151       False
# 1        0          PC 17599  71.2833   C85         0.139136        True
# 2        0  STON/O2. 3101282   7.9250   NaN         0.015469       False
# 3        0            113803  53.1000  C123         0.103644       False
# 4        0            373450   8.0500   NaN         0.015713       False
# ..     ...               ...      ...   ...              ...         ...
# 886      0            211536  13.0000   NaN         0.025374       False
# 887      0            112053  30.0000   B42         0.058556       False
# 888      2        W./C. 6607  23.4500   NaN         0.045771       False
# 889      0            111369  30.0000  C148         0.058556        True
# 890      0            370376   7.7500   NaN         0.015127       False
#
#      Embarked_Q  Embarked_S
# 0         False        True
# 1         False       False
# 2         False        True
# 3         False        True
# 4         False        True
# ..          ...         ...
# 886       False        True
# 887       False        True
# 888       False        True
# 889       False       False
# 890        True       False
#
# [891 rows x 15 columns]
